# %% [markdown]
# # London Subway Optimization
# In this project, we analysed the flow capacity of the London Subway System in many ways. The goal of the project was to propose the most cost-effective improvement to maximise the commuter flow in the network, and was mostly solved using the Gurobi Python library.
#
# For this project we will use data on the London subway. The data is organized as follows:
# - file ''connections'' contains data on the direct links between two stations; for instance, we can go from Station 11 to Station 163 (and vice versa) by taking line 1; it will take us 1 minute;
# - file ''stations'' contains information on identifiers of each station;
# - file ''stations_restricted'' contains a subset of the stations from stations.csv
#
# From this information, we can construct a network as follows:
# - the nodes are the stations;
# - there is an arc between two nodes if there is a direct link between the two corresponding stations in the file ''connections'' (assume every connection corresponds to two arcs in opposite directions); for instance, there is an arc (11,163), and arc (163,11), but no arc (1,170);
# - define capacities as follows:
# 1.   Generate a random number between 5 and 10 for each line: this is the capacity of the line.
# 2.   The capacity of an arc between two stations has the same capacity as the sum of the capacities of the lines that link them. For instance, the stations of King's Cross St. Pancras (#145) and Euston Square (#90) are linked by lines 3,6,8. Let's say we randomly sampled the capacity of 6,8,4 for lines 3,6,8. The capacity of the arc (145,90) is 6+8+4=18. Similarly, the capacity of the arc (90,145) is also 6+8+4=18.
#
# The project is composed of 4 questions, all to be solved using Linear Program and to be completed in this order:
#
# 1. We want to compute how many passengers can transit on average from the north-east part of the city center, to the south-west. To do so, compute a maximum flow between King's Cross St. Pancras (#145) and Hammersmith (#110) on the instance in the file ''connections'' (ignore the time it takes to go between stations).
# 2. We want to understand how many people can be evacuated from the city center within 18 minutes. To do so, restrict to the stations in the file ''stations_restricted'' (and the corresponding arcs). Compute the maximum flow over time between King's Cross St. Pancras (#145) and Victoria (#273) for T=18.
# 3. Consider again the restriction to the stations in the file ''stations_restricted''. For security reasons, in the stations Oxford Circus (#192) and Embankment (#87), at any given time there can be at most 20 passengers in transit. Solve problem 2) above under this additional restriction.
# 4. **4) Will not be evaluated unless parts 1),2),3) have been correctly solved** Choose an improvement to the line and write a linear program that finds the *best* way to realize your improvement. For instance, you could assume you have a budget of 10 units of additional capacity to be added to the network, and you want to decide where to add them so that the maximum flow in part 1) above increases the most (it is ok to have an improvement that requires an integer solution, but the solution you get is fractional).

# %% [markdown]
# #Data Input#

# %%
# Import libraries
import pandas as pd
import numpy as np
# %pip install gurobipy
import gurobipy as gp
# Out:
# Requirement already satisfied: gurobipy in /usr/local/lib/python3.10/dist-packages (11.0.3)

# %% [markdown]
# Upload and inspection of first data set (connections)

# %%
# Set working directory
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read connections File
df = pd.read_csv('/content/drive/My Drive/Project 1 Optimization/connections.csv')
print(df.head())

# Read stations list file
stations_list = pd.read_csv('/content/drive/My Drive/Project 1 Optimization/stations.csv')
print(stations_list.head())
# Out:
#    link name  station1  station2  line  time  distance(miles)
# 0        338         1        73    10   2.0         0.612553
# 1        339         1       234    10   4.0         1.170653
# 2        340         1       265    10   3.0         1.214326
# 3         73         2       156     3   2.0         0.379161
# 4         74         2       263     3   4.0         0.314278
#    Station code          name  zone  total_lines
# 0             1    Acton Town   3.0          2.0
# 1             2       Aldgate   1.0          2.0
# 2             3  Aldgate East   1.0          2.0
# 3             4    All Saints   2.0          1.0
# 4             5      Alperton   4.0          1.0

# %% [markdown]
# Generate random capacities for each line and add them to df

# %%
# Set seed to make it reproducable
np.random.seed(14)

# For each unique line generate a random (integer) capacity from 5 to 10
lines = df['line'].unique()
lines_capacities = pd.DataFrame({'line': lines, 'line_capacity': np.random.randint(5, 11, len(lines))})
print (lines_capacities)

# Add a column to df with the capacity of the line
df = pd.merge(df, lines_capacities, how='left', on='line')
# Out:
#     line  line_capacity
# 0     10              8
# 1      3              5
# 2      8              9
# 3      4              6
# 4      6              7
# 5     13              9
# 6      9              7
# 7      1              5
# 8      7             10
# 9      2              5
# 10    12             10
# 11    11              7
# 12    14              6
# 13     5              8

# %%
df.head()
# Out:
#    link name  station1  station2  line  time  distance(miles)  line_capacity
# 0        338         1        73    10   2.0         0.612553              8
# 1        339         1       234    10   4.0         1.170653              8
# 2        340         1       265    10   3.0         1.214326              8
# 3         73         2       156     3   2.0         0.379161              5
# 4         74         2       263     3   4.0         0.314278              5

# %% [markdown]
# Capacities for each arc between two stations

# %%
# We will construct a dictionary where the value of (i, j) will correspond to the total capacity of the arc connecting i and j
# Initialize dictionary
c = {}

# Loop to get the total capacity of an arc connecting 2 stations by adding the capacities of all the lines that connect them
for index, row in df.iterrows():
  s1 = int(row['station1'])
  s2 = int(row['station2'])
  capacity_line = int(row['line_capacity'])
  # Add capcity of new link between s1 and s2 to total capacity of arc s1 -> s2 (and s2 -> s1, since bidirectional network)
  c[(s1, s2)] = c.get((s1, s2), 0) + capacity_line
  c[(s2, s1)] = c.get((s2, s1), 0) + capacity_line

# %%
print(dict(sorted(c.items(), key=lambda item: (item[0][0], item[0][1]))))
# Out:
# {(1, 52): 6, (1, 73): 14, (1, 234): 8, (1, 265): 8, (2, 156): 14, (2, 263): 5, (3, 156): 7, (3, 263): 6, (3, 295): 13, (4, 70): 9, (4, 201): 9, (5, 194): 8, (5, 252): 8, (6, 46): 9, (7, 145): 7, (7, 188): 7, (8, 124): 7, (8, 264): 7, (9, 31): 8, (9, 232): 8, (10, 95): 8, (10, 128): 8, (11, 28): 10, (11, 83): 12, (11, 94): 9, (11, 104): 21, (11, 163): 5, (11, 212): 5, (11, 249): 10, (12, 56): 7, (12, 257): 7, (13, 156): 5, (13, 157): 7, (13, 167): 7, (13, 225): 9, (13, 250): 5, (13, 279): 10, (14, 92): 21, (14, 167): 21, (15, 78): 13, (15, 269): 6, (16, 91): 5, (16, 173): 5, (17, 74): 8, (17, 110): 14, (17, 293): 6, (18, 186): 11, (18, 193): 11, (19, 97): 9, (20, 65): 9, (20, 217): 9, (21, 67): 6, (21, 269): 6, (22, 47): 7, (22, 111): 7, (23, 41): 10, (23, 157): 10, (24, 156): 5, (24, 164): 5, (25, 161): 11, (25, 255): 11, (26, 260): 7, (26, 274): 7, (27, 79): 9, (27, 201): 9, (28, 11): 10, (28, 107): 10, (28, 162): 5, (28, 192): 5, (28, 193): 6, (28, 259): 6, (29, 84): 7, (29, 157): 7, (30, 176): 8, (30, 190): 8, (31, 9): 8, (31, 303): 8, (32, 70): 9, (32, 204): 9, (33, 36): 13, (33, 164): 13, (34, 100): 7, (34, 119): 7, (35, 245): 7, (36, 33): 13, (36, 289): 13, (37, 158): 5, (37, 301): 5, (38, 58): 7, (38, 81): 7, (39, 128): 8, (39, 145): 8, (40, 47): 7, (40, 89): 7, (40, 139): 7, (40, 170): 7, (41, 23): 10, (41, 42): 10, (41, 216): 8, (41, 253): 8, (42, 41): 10, (42, 63): 6, (42, 120): 9, (42, 183): 10, (42, 292): 9, (42, 295): 6, (43, 79): 9, (43, 183): 10, (43, 219): 9, (43, 289): 10, (44, 161): 11, (44, 166): 11, (45, 207): 10, (45, 243): 10, (46, 6): 9, (46, 50): 9, (46, 53): 9, (47, 22): 7, (47, 40): 7, (48, 126): 5, (48, 250): 5, (49, 87): 12, (49, 151): 7, (49, 197): 5, (50, 46): 9, (51, 103): 5, (51, 215): 5, (52, 1): 6, (52, 265): 6, (53, 46): 9, (53, 214): 9, (54, 55): 7, (54, 56): 7, (55, 54): 7, (55, 245): 7, (56, 12): 7, (56, 54): 7, (57, 187): 8, (58, 38): 7, (58, 119): 7, (59, 240): 7, (59, 258): 7, (60, 126): 8, (60, 151): 8, (61, 171): 9, (61, 238): 9, (62, 168): 9, (62, 280): 9, (63, 42): 6, (63, 203): 9, (63, 219): 9, (63, 305): 6, (64, 106): 9, (64, 135): 9, (65, 20): 9, (65, 97): 9, (66, 67): 6, (66, 85): 6, (67, 21): 6, (67, 66): 6, (68, 158): 5, (68, 256): 5, (69, 86): 9, (69, 106): 9, (70, 4): 9, (70, 32): 9, (71, 172): 10, (71, 297): 10, (72, 73): 6, (72, 286): 5, (73, 1): 14, (73, 72): 6, (73, 182): 8, (74, 17): 8, (74, 99): 14, (74, 122): 6, (74, 138): 6, (74, 287): 6, (74, 293): 6, (75, 210): 17, (75, 222): 17, (76, 181): 5, (76, 296): 5, (77, 93): 7, (77, 124): 7, (78, 15): 13, (78, 270): 13, (79, 27): 9, (79, 43): 9, (80, 205): 6, (80, 231): 6, (81, 38): 7, (82, 163): 5, (82, 193): 5, (83, 11): 12, (83, 193): 18, (84, 29): 7, (84, 136): 7, (84, 148): 5, (85, 66): 6, (85, 129): 6, (86, 69): 9, (86, 152): 9, (87, 49): 12, (87, 255): 11, (87, 279): 12, (87, 285): 11, (88, 256): 5, (89, 40): 7, (89, 145): 14, (89, 170): 7, (89, 277): 14, (90, 104): 21, (90, 145): 21, (91, 16): 5, (91, 109): 5, (92, 14): 21, (92, 145): 21, (92, 156): 6, (92, 259): 6, (93, 77): 7, (93, 165): 7, (93, 288): 7, (94, 11): 9, (94, 254): 10, (94, 282): 9, (94, 290): 10, (95, 10): 8, (95, 123): 7, (95, 160): 8, (95, 224): 7, (96, 195): 6, (96, 287): 6, (97, 19): 9, (97, 65): 9, (98, 173): 5, (98, 211): 5, (99, 74): 14, (99, 122): 5, (99, 236): 19, (100, 34): 7, (100, 111): 7, (101, 110): 7, (101, 227): 7, (102, 259): 7, (102, 277): 7, (103, 51): 5, (103, 109): 5, (104, 11): 21, (104, 90): 21, (105, 177): 5, (105, 196): 5, (106, 64): 9, (106, 69): 9, (107, 28): 10, (107, 133): 8, (107, 192): 7, (107, 197): 8, (107, 273): 7, (107, 285): 10, (108, 141): 6, (108, 265): 6, (109, 91): 5, (109, 103): 5, (110, 17): 14, (110, 101): 7, (110, 209): 6, (110, 265): 8, (111, 22): 7, (111, 100): 7, (112, 181): 5, (112, 196): 5, (113, 246): 5, (113, 298): 5, (114, 140): 5, (115, 178): 9, (115, 184): 9, (115, 291): 9, (116, 117): 8, (116, 118): 8, (116, 132): 8, (117, 116): 8, (117, 118): 8, (118, 116): 8, (118, 117): 8, (119, 34): 7, (119, ...

# %% [markdown]
# #Problem 1:#
# We want to solve the max flow problem between Hammersmith (#110) and King's Cross St. Pancras (#145). The max flow is the same in both directions as the network is undirected

# %%
# Fixed parameters
stations = set(df['station1']).union(set(df['station2'])) # List all unique stations
source = 110
sink = 145

# Initialize a LP model
m1 = gp.Model()

# Variables: x[i, j] >= 0 representing the flow frow station i to j
# One variable for each arc with positive capacity
x = {}
for (s1, s2), capacity in c.items():
  x[(s1, s2)] = m1.addVar(lb=0, ub=capacity, vtype=gp.GRB.INTEGER) # Note we already included the non-negativity and capacity constraints

# Add conservation of flow constraint
for s in stations:
  if s == source or s == sink: continue
  else:
    # flow entering a node = flow leaving it
    m1.addConstr(sum(x[(n, s)] for n in stations if (n, s) in x) == sum(x[(s, n)] for n in stations if (s, n) in x))

# Set objective function: maximize net flux arriving at Hammersmith
# Note: maximizing net flux leaving King's cross would be equivalent
m1.setObjective(sum(x[(n, sink)] - x[(sink, n)] for n in stations if (n, sink) in x), gp.GRB.MAXIMIZE)

# Optimize the model
m1.optimize()
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 320 rows, 752 columns and 1482 nonzeros
# Model fingerprint: 0x8b86761a
# Variable types: 0 continuous, 752 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e+00, 2e+01]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 286 rows and 674 columns
# Presolve time: 0.00s
# Presolved: 34 rows, 78 columns, 146 nonzeros
# Variable types: 0 continuous, 78 integer (0 binary)
# Found heuristic solution: objective 1.0000000
#
# Root relaxation: objective 3.400000e+01, 51 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      34.0000000   34.00000  0.00%     -    0s
#
# Explored 1 nodes (51 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 34 1 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.400000000000e+01, best bound 3.400000000000e+01, gap 0.0000%

# %%
# Output of the results
print(f"\nMaximum flow from station 145 to 110: {m1.objVal}")
for (st1, st2), x_opt in x.items():
  if x_opt.X > 0:  # We only care about positive flows
    print(f"Flow from station {st1} to station {st2}: {x_opt.X}")
# Out:
# Maximum flow from station 145 to 110: 34.0
# Flow from station 1 to station 73: 14.0
# Flow from station 73 to station 1: 1.0
# Flow from station 265 to station 1: 8.0
# Flow from station 2 to station 156: 14.0
# Flow from station 156 to station 2: 9.0
# Flow from station 263 to station 2: 5.0
# Flow from station 3 to station 263: 6.0
# Flow from station 295 to station 3: 13.0
# Flow from station 3 to station 156: 7.0
# Flow from station 4 to station 70: 9.0
# Flow from station 70 to station 4: 4.0
# Flow from station 201 to station 4: 5.0
# Flow from station 194 to station 5: 8.0
# Flow from station 5 to station 252: 8.0
# Flow from station 7 to station 145: 7.0
# Flow from station 188 to station 7: 7.0
# Flow from station 95 to station 10: 7.0
# Flow from station 10 to station 128: 7.0
# Flow from station 212 to station 11: 5.0
# Flow from station 83 to station 11: 12.0
# Flow from station 11 to station 104: 21.0
# Flow from station 11 to station 28: 10.0
# Flow from station 28 to station 11: 6.0
# Flow from station 11 to station 249: 1.0
# Flow from station 94 to station 11: 9.0
# Flow from station 13 to station 156: 5.0
# Flow from station 13 to station 250: 5.0
# Flow from station 13 to station 225: 9.0
# Flow from station 225 to station 13: 8.0
# Flow from station 13 to station 157: 7.0
# Flow from station 157 to station 13: 4.0
# Flow from station 167 to station 13: 4.0
# Flow from station 279 to station 13: 10.0
# Flow from station 14 to station 92: 10.0
# Flow from station 167 to station 14: 10.0
# Flow from station 16 to station 91: 5.0
# Flow from station 173 to station 16: 5.0
# Flow from station 110 to station 17: 14.0
# Flow from station 17 to station 293: 6.0
# Flow from station 17 to station 74: 8.0
# Flow from station 186 to station 18: 11.0
# Flow from station 18 to station 193: 11.0
# Flow from station 23 to station 41: 10.0
# Flow from station 157 to station 23: 10.0
# Flow from station 156 to station 24: 5.0
# Flow from station 24 to station 164: 5.0
# Flow from station 161 to station 25: 1.0
# Flow from station 25 to station 255: 11.0
# Flow from station 255 to station 25: 10.0
# Flow from station 27 to station 79: 5.0
# Flow from station 79 to station 27: 9.0
# Flow from station 27 to station 201: 9.0
# Flow from station 201 to station 27: 5.0
# Flow from station 162 to station 28: 5.0
# Flow from station 28 to station 192: 5.0
# Flow from station 28 to station 107: 10.0
# Flow from station 193 to station 28: 6.0
# Flow from station 84 to station 29: 7.0
# Flow from station 29 to station 157: 7.0
# Flow from station 32 to station 70: 4.0
# Flow from station 70 to station 32: 9.0
# Flow from station 32 to station 204: 9.0
# Flow from station 204 to station 32: 4.0
# Flow from station 36 to station 33: 13.0
# Flow from station 33 to station 164: 13.0
# Flow from station 289 to station 36: 13.0
# Flow from station 128 to station 39: 7.0
# Flow from station 39 to station 145: 8.0
# Flow from station 145 to station 39: 1.0
# Flow from station 40 to station 89: 7.0
# Flow from station 170 to station 40: 7.0
# Flow from station 41 to station 216: 8.0
# Flow from station 41 to station 42: 2.0
# Flow from station 42 to station 183: 10.0
# Flow from station 295 to station 42: 5.0
# Flow from station 43 to station 79: 4.0
# Flow from station 43 to station 219: 3.0
# Flow from station 183 to station 43: 10.0
# Flow from station 43 to station 289: 10.0
# Flow from station 289 to station 43: 7.0
# Flow from station 44 to station 161: 11.0
# Flow from station 161 to station 44: 10.0
# Flow from station 166 to station 44: 1.0
# Flow from station 48 to station 126: 5.0
# Flow from station 250 to station 48: 5.0
# Flow from station 49 to station 87: 12.0
# Flow from station 87 to station 49: 10.0
# Flow from station 49 to station 197: 5.0
# Flow from station 151 to station 49: 7.0
# Flow from station 103 to station 51: 5.0
# Flow from station 51 to station 215: 5.0
# Flow from station 52 to station 1: 6.0
# Flow from station 1 to station 52: 1.0
# Flow from station 52 to station 265: 1.0
# Flow from station 265 to station 52: 6.0
# Flow from station 126 to station 60: 8.0
# Flow from station 60 to station 151: 8.0
# Flow from station 219 to station 63: 3.0
# Flow from station 63 to station 42: 6.0
# Flow from station 42 to station 63: 3.0
# Flow from station 172 to station 71: 10.0
# Flow from station 71 to station 297: 10.0
# Flow from station 72 to station 286: 5.0
# Flow from station 73 to station 72: 5.0
# Flow from station 73 to station 182: 8.0
# Flow from station 74 to station 99: 14.0
# Flow from station 99 to station 74: 6.0
# Flow from station 74 to station 122: 6.0
# Flow from station 293 to station 74: 6.0
# Flow from station 181 to station 76: 5.0
# Flow from station 76 to station 296: 5.0
# Flow from station 193 to station 83: 12.0
# Flow from station 148 to station 84: 5.0
# Flow from station 136 to station 84: 2.0
# Flow from station 87 to station 279: 12.0
# Flow from station 87 to station 255: 10.0
# Flow from station 255 to station 87: 11.0
# Flow from station 285 to station 87: 9.0
# Flow from station 89 to station 145: 14.0
# Flow from station 89 to station 170: 7.0
# Flow from station 277 to station 89: 14.0
# Flow from station 104 to station 90: 21.0
# Flow from station 90 to station 145: 21.0
# Flow from station 91 to station 109: 5.0
# Flow from station 92 to station 259: 4.0
# Flow from station 94 to station 254: 9.0
# Flow from station 254 to station 94: 10.0
# Flow from station 290 to station 94: 10.0
# Flow from station 94 to station 282: 9.0
# Flow from station 282 to station 94: 7.0
# Flow from station 123 to station 95: 7.0
# Flow from station 98 to station 173: 5.0
# Flow from station 211 to station 98: 5.0
# Flow from station 99 to station 122: 5.0
# Flow from station 99 to station 236: 19.0
# Flow from station 236 to station 99: 16.0
# Flow from station 110 to station 101: 7.0
# Flow from station 101 to station 227: 7.0
# Flow from station 259 to station 102: 7.0
# Flow from station 102 to station 277: 7.0
# Flow from station 109 to station 103: 5.0
# Flow from station 107 to station 285: 10.0
# Flow from station 285 to station 107: 2.0
# Flow from station 107 to station 133: 8.0
# Flow from station 197 to station 107: 8.0
# Flow from station 107 to station 192: 7.0
# Flow from station 107 to station 273: 2.0
# Flow from station 273 to station 107: 7.0
# Flow from station 110 to station 209: 6.0
# Flow from station 110 to station 265: 7.0
# Flow from station 115 to station 178: 9.0
# Flow from station 178 to station 115: 1.0
# Flow from station 115 to station 291: 1.0
# Flow from station 291 to station 115: 9.0
# Flow from station 117 to station 116: 8.0
# Flow from station 116 to station 118: 8.0
# Flow from station 118 to station 117: 8.0
# Flow from station 122 to station 186: 11.0
# Flow from station 145 to station 123: 7.0
# Flow from station 126 to station 259: 5.0
# Flow from station 223 to station 126: 8.0
# Flow from station 127 to station 186: 5.0
# Flow from station 226 to station 127: 5.0
# Flow from station 133 to station 146: 8.0
# Flow from station 136 to station 191: 5.0
# Flow from station 279 to station 136: 7.0
# Flow from station 142 to station 290: 10.0
# Flow from station 297 to station 142: 10.0
# Flow from station 145 to station 223: 8.0
# Flow from station 146 to station 236: 8.0
# Flow from station 150 to station 147: 7.0
# Flow from station 147 to station 283: 7.0
# Flow from station 279 to station 148: 5.0
# Flow from station 149 to station 162: 5.0
# Flow from station 208 to station 149: 5.0
# Flow from station 227 to station 150: 7.0
# Flow from station 259 to station 151: 7.0
# Flow from station 151 to station 197: 8.0
# Flow from station 230 to station 154: 5.0
# Flow from station 154 to station 275: 5.0
# Flow from station 225 to station 155: 1.0
# Flow from station 155 to station 284: 1.0
# Flow from station 156 to station 167: 21.0
# Flow from station 92 to station 156: 6.0
# Flow from station 164 to station 247: 5.0
# Flow from station 164 to station 244: 13.0
# Flow from station 263 to station 166: 1.0
# Flow from station 167 to station 188: 7.0
# Flow from station 282 to station 172: 10.0
# Flow from station 178 to station 202: 8.0
# Flow from station 286 to station 181: 5.0
# Flow from station 182 to station 194: 8.0
# Flow from station 186 to station 208: 5.0
# Flow from station 191 to station 245: 5.0
# Flow from station 197 to station 192: 5.0
# Flow from station 192 to station 212: 5.0
# Flow from station 192 to station 259: 5.0
# Flow from station 192 to station 277: 7.0
# Flow from station 218 to station 193: 7.0
# Flow from station 198 to station 272: 2.0
# Flow from station 272 to station 198: 7.0
# Flow from station 198 to station 273: 7.0
# Flow from station 273 to station 198: 2.0
# Flow from station 201 to station 284: 9.0
# Flow from station 284 to station 201: 1.0
# Flow from station 292 to station 201: 9.0
# Flow from station 202 to station 282: 9.0
# Flow from station 282 to station 202: 1.0
# Flow from station 204 to station 247: 9.0
# Flow from station 247 to station 204: 4.0
# Flow from station 209 to station 242: 6.0
# Flow from station 210 to station 291: 9.0
# Flow from station 291 to station 210: 1.0
# Flow from station 235 to station 210: 8.0
# Flow from station 275 to station 211: 5.0
# Flow from station 215 to station 301: 5.0
# Flow from station 216 to station 276: 8.0
# Flow from station 283 to station 218: 7.0
# Flow from station 276 to station 225: 8.0
# Flow from station 225 to station 295: 8.0
# Flow from station 296 to station 226: 5.0
# Flow from station 236 to station 229: 11.0
# Flow from station 229 to station 273: 11.0
# Flow from station 241 to station 230: 5.0
# Flow from station 251 to station 235: 8.0
# Flow from station 301 to station 241: 5.0
# Flow from station 242 to station 265: 6.0
# Flow from station 244 to station 295: 13.0
# Flow from station 245 to station 272: 7.0
# Flow from station 272 to station 245: 2.0
# Flow from station 247 to station 289: 10.0
# Flow from station 273 to station 248: 11.0
# Flow from station 248 to station 285: 11.0
# Flow from station 249 to station 254: 1.0
# Flow from station 252 to station 251: 8.0
# Flow from station 285 to station 279: 10.0
# Flow from station 284 to station 292: 9.0
# Flow from station 295 to station 156: 6.0
# Flow from station 156 to station 295: 3.0

# %% [markdown]
# #Problem 2:#
# How many people can be evacuated from #145 to #273 within 18 minutes.

# %% [markdown]
# Read *stations_restricted.csv* to find out what stations to consider for this problem (and problem 3)

# %%
# Read stations list file
stations_restricted = pd.read_csv('/content/drive/My Drive/Project 1 Optimization/stations_restricted.csv')

# Create new data frame = subset of df (where stations in stations_restricted)
df_restricted = df[
    df['station1'].isin(stations_restricted['Station code']) &
    df['station2'].isin(stations_restricted['Station code'])
]

# %%
# Create a dictionary that for every connection i to j it returns the duration of the ride
duration = {}
for index, row in df_restricted.iterrows():
  s1 = int(row['station1'])
  s2 = int(row['station2'])
  # Check for NA in time
  if pd.isna(row['time']):
    print(f'Connection between {s1} and {s2} has an undefined duration! We assign a time =  1 min')
    duration_line = 1 # if NA we will (arbitrarily) assign it a value of 1
  else: duration_line = int(row['time'])

  if duration.get((s1, s2)) or duration.get((s2, s1)):
    if duration[(s1, s2)] != duration_line or duration[(s1, s2)] != duration_line:
      print(f'There are connections between {s1} and {s2} with different duration times')
  else:
    duration[(s1, s2)] = duration_line
    duration[(s2, s1)] = duration_line
# Out:
# Connection between 259 and 28 has an undefined duration! We assign a time =  1 min

# %%
print(duration)
print(max(duration.values()), min(duration.values()))
# Out:
# {(11, 212): 2, (212, 11): 2, (11, 104): 3, (104, 11): 3, (11, 28): 2, (28, 11): 2, (28, 192): 1, (192, 28): 1, (28, 107): 2, (107, 28): 2, (49, 87): 1, (87, 49): 1, (49, 197): 2, (197, 49): 2, (49, 151): 2, (151, 49): 2, (60, 126): 1, (126, 60): 1, (60, 151): 1, (151, 60): 1, (87, 285): 2, (285, 87): 2, (89, 145): 2, (145, 89): 2, (89, 277): 1, (277, 89): 1, (90, 104): 2, (104, 90): 2, (90, 145): 2, (145, 90): 2, (102, 259): 1, (259, 102): 1, (102, 277): 2, (277, 102): 2, (107, 285): 3, (285, 107): 3, (107, 197): 1, (197, 107): 1, (107, 192): 2, (192, 107): 2, (107, 273): 2, (273, 107): 2, (126, 259): 2, (259, 126): 2, (126, 223): 2, (223, 126): 2, (145, 223): 2, (223, 145): 2, (151, 259): 1, (259, 151): 1, (151, 197): 2, (197, 151): 2, (192, 197): 2, (197, 192): 2, (192, 212): 2, (212, 192): 2, (192, 259): 2, (259, 192): 2, (192, 277): 2, (277, 192): 2, (248, 273): 2, (273, 248): 2, (248, 285): 2, (285, 248): 2, (259, 28): 1, (28, 259): 1}
# 3 1

# %%
# Fixed parameters
stations_rest = stations_restricted['Station code'].unique() # list of all unique restricted stations
origin = 145
destination = 273
T = 18 # time for evacuation

# Initialize a LP model
m2 = gp.Model()

# Variables: y(s1, s2, t) represents the flow leaving from s1 towards s2 at instant t
y = {}
for (s1, s2), d in duration.items():
  for t in range(T+1):
    if t + d <= T:
      y[(s1, s2, t)] = m2.addVar(lb=0, ub=c[((s1, s2))], vtype=gp.GRB.INTEGER) # Note we already included the non-negativity and capacity constraints

# Add constraints
# Conservation of flow constraint subject to time-constraint
for s in stations_rest:
  if s == origin or s == destination: continue
  else:
    # flow entering a node = flow leaving it at any given time
    for t in range(T+1):
      m2.addConstr(sum(y.get((s, n, t), 0) for n in stations_rest) == \
                   sum(y.get((n, s, t - duration.get((n, s), 0)), 0) for n in stations_rest))

# Set objective function: maximize net flux arriving at Victoria during the 18 minutes
obj_fun_2 = sum(y.get((n, destination, t), 0) - y.get((destination, n, t), 0)
                for n in stations_rest for t in range(T+1))

m2.setObjective(obj_fun_2, gp.GRB.MAXIMIZE)

# Optimize the model
m2.optimize()
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 380 rows, 1136 columns and 2102 nonzeros
# Model fingerprint: 0x98bec04a
# Variable types: 0 continuous, 1136 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e+00, 2e+01]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 273 rows and 790 columns
# Presolve time: 0.01s
# Presolved: 107 rows, 346 columns, 650 nonzeros
# Found heuristic solution: objective 14.0000000
# Variable types: 0 continuous, 346 integer (0 binary)
# Found heuristic solution: objective 21.0000000
#
# Root relaxation: objective 1.100000e+02, 123 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     110.0000000  110.00000  0.00%     -    0s
#
# Explored 1 nodes (123 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 110 21 14 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+02, best bound 1.100000000000e+02, gap 0.0000%

# %%
# Output of the results
print(f"\nMaximum flow for evacuation under 18 min from station 145 to 273: {m2.objVal}")

for (st1, st2, t), y_opt in sorted(y.items(), key=lambda item: item[0][2]):  # Sort by t
    if y_opt.X > 0:  # Only care about positive flows
        print(f"Flow from station {st1} to station {st2} @ instant {t}: {y_opt.X}")
# Out:
# Maximum flow for evacuation under 18 min from station 145 to 273: 110.0
# Flow from station 145 to station 89 @ instant 0: 14.0
# Flow from station 145 to station 90 @ instant 0: 10.0
# Flow from station 145 to station 223 @ instant 0: 8.0
# Flow from station 145 to station 89 @ instant 1: 14.0
# Flow from station 145 to station 90 @ instant 1: 10.0
# Flow from station 145 to station 223 @ instant 1: 8.0
# Flow from station 145 to station 89 @ instant 2: 14.0
# Flow from station 89 to station 277 @ instant 2: 14.0
# Flow from station 90 to station 104 @ instant 2: 10.0
# Flow from station 145 to station 90 @ instant 2: 2.0
# Flow from station 223 to station 126 @ instant 2: 8.0
# Flow from station 145 to station 223 @ instant 2: 1.0
# Flow from station 145 to station 89 @ instant 3: 7.0
# Flow from station 89 to station 277 @ instant 3: 14.0
# Flow from station 90 to station 104 @ instant 3: 10.0
# Flow from station 145 to station 90 @ instant 3: 2.0
# Flow from station 277 to station 102 @ instant 3: 7.0
# Flow from station 223 to station 126 @ instant 3: 8.0
# Flow from station 145 to station 223 @ instant 3: 4.0
# Flow from station 277 to station 192 @ instant 3: 7.0
# Flow from station 104 to station 11 @ instant 4: 10.0
# Flow from station 126 to station 60 @ instant 4: 8.0
# Flow from station 89 to station 277 @ instant 4: 14.0
# Flow from station 90 to station 104 @ instant 4: 2.0
# Flow from station 145 to station 90 @ instant 4: 7.0
# Flow from station 277 to station 102 @ instant 4: 7.0
# Flow from station 223 to station 126 @ instant 4: 1.0
# Flow from station 277 to station 192 @ instant 4: 7.0
# Flow from station 104 to station 11 @ instant 5: 10.0
# Flow from station 126 to station 60 @ instant 5: 8.0
# Flow from station 60 to station 151 @ instant 5: 8.0
# Flow from station 89 to station 277 @ instant 5: 7.0
# Flow from station 90 to station 104 @ instant 5: 2.0
# Flow from station 145 to station 90 @ instant 5: 7.0
# Flow from station 102 to station 259 @ instant 5: 7.0
# Flow from station 277 to station 102 @ instant 5: 7.0
# Flow from station 192 to station 107 @ instant 5: 7.0
# Flow from station 223 to station 126 @ instant 5: 4.0
# Flow from station 277 to station 192 @ instant 5: 7.0
# Flow from station 104 to station 11 @ instant 6: 2.0
# Flow from station 151 to station 49 @ instant 6: 7.0
# Flow from station 126 to station 60 @ instant 6: 1.0
# Flow from station 60 to station 151 @ instant 6: 8.0
# Flow from station 145 to station 89 @ instant 6: 2.0
# Flow from station 90 to station 104 @ instant 6: 7.0
# Flow from station 102 to station 259 @ instant 6: 7.0
# Flow from station 192 to station 107 @ instant 6: 7.0
# Flow from station 259 to station 151 @ instant 6: 1.0
# Flow from station 151 to station 197 @ instant 6: 1.0
# Flow from station 277 to station 192 @ instant 6: 7.0
# Flow from station 259 to station 28 @ instant 6: 6.0
# Flow from station 104 to station 11 @ instant 7: 2.0
# Flow from station 11 to station 28 @ instant 7: 10.0
# Flow from station 192 to station 28 @ instant 7: 2.0
# Flow from station 28 to station 107 @ instant 7: 6.0
# Flow from station 151 to station 49 @ instant 7: 7.0
# Flow from station 126 to station 60 @ instant 7: 4.0
# Flow from station 60 to station 151 @ instant 7: 1.0
# Flow from station 90 to station 104 @ instant 7: 7.0
# Flow from station 102 to station 259 @ instant 7: 7.0
# Flow from station 192 to station 107 @ instant 7: 5.0
# Flow from station 107 to station 273 @ instant 7: 7.0
# Flow from station 259 to station 151 @ instant 7: 6.0
# Flow from station 151 to station 197 @ instant 7: 2.0
# Flow from station 259 to station 28 @ instant 7: 1.0
# Flow from station 104 to station 11 @ instant 8: 7.0
# Flow from station 11 to station 28 @ instant 8: 10.0
# Flow from station 28 to station 107 @ instant 8: 3.0
# Flow from station 49 to station 87 @ instant 8: 7.0
# Flow from station 197 to station 49 @ instant 8: 1.0
# Flow from station 151 to station 49 @ instant 8: 7.0
# Flow from station 60 to station 151 @ instant 8: 4.0
# Flow from station 89 to station 277 @ instant 8: 2.0
# Flow from station 107 to station 285 @ instant 8: 4.0
# Flow from station 192 to station 107 @ instant 8: 7.0
# Flow from station 107 to station 273 @ instant 8: 3.0
# Flow from station 259 to station 151 @ instant 8: 3.0
# Flow from station 259 to station 28 @ instant 8: 4.0
# Flow from station 104 to station 11 @ instant 9: 7.0
# Flow from station 11 to station 28 @ instant 9: 2.0
# Flow from station 28 to station 192 @ instant 9: 5.0
# Flow from station 28 to station 107 @ instant 9: 9.0
# Flow from station 49 to station 87 @ instant 9: 7.0
# Flow from station 197 to station 49 @ instant 9: 2.0
# Flow from station 151 to station 49 @ instant 9: 7.0
# Flow from station 87 to station 285 @ instant 9: 7.0
# Flow from station 107 to station 285 @ instant 9: 4.0
# Flow from station 107 to station 273 @ instant 9: 7.0
# Flow from station 277 to station 192 @ instant 9: 2.0
# Flow from station 11 to station 28 @ instant 10: 2.0
# Flow from station 28 to station 192 @ instant 10: 3.0
# Flow from station 192 to station 28 @ instant 10: 5.0
# Flow from station 28 to station 107 @ instant 10: 7.0
# Flow from station 49 to station 87 @ instant 10: 8.0
# Flow from station 87 to station 285 @ instant 10: 7.0
# Flow from station 107 to station 285 @ instant 10: 3.0
# Flow from station 107 to station 273 @ instant 10: 7.0
# Flow from station 11 to station 28 @ instant 11: 7.0
# Flow from station 192 to station 28 @ instant 11: 5.0
# Flow from station 28 to station 107 @ instant 11: 7.0
# Flow from station 49 to station 87 @ instant 11: 9.0
# Flow from station 87 to station 285 @ instant 11: 8.0
# Flow from station 107 to station 285 @ instant 11: 2.0
# Flow from station 107 to station 273 @ instant 11: 7.0
# Flow from station 285 to station 248 @ instant 11: 11.0
# Flow from station 11 to station 28 @ instant 12: 7.0
# Flow from station 28 to station 107 @ instant 12: 7.0
# Flow from station 87 to station 285 @ instant 12: 9.0
# Flow from station 107 to station 273 @ instant 12: 7.0
# Flow from station 285 to station 248 @ instant 12: 11.0
# Flow from station 28 to station 107 @ instant 13: 7.0
# Flow from station 107 to station 273 @ instant 13: 7.0
# Flow from station 248 to station 273 @ instant 13: 11.0
# Flow from station 285 to station 248 @ instant 13: 11.0
# Flow from station 28 to station 107 @ instant 14: 7.0
# Flow from station 107 to station 273 @ instant 14: 7.0
# Flow from station 248 to station 273 @ instant 14: 11.0
# Flow from station 285 to station 248 @ instant 14: 11.0
# Flow from station 107 to station 273 @ instant 15: 7.0
# Flow from station 248 to station 273 @ instant 15: 11.0
# Flow from station 107 to station 273 @ instant 16: 7.0
# Flow from station 248 to station 273 @ instant 16: 11.0

# %% [markdown]
# #Problem 3:#
# Same evacuation problem as P2, but additionally: for security reasons, in the stations Oxford Circus (#192) and Embankment (#87), at any given time there can be at most 20 passengers in transit.

# %%
# Parameters
# Note: same fixed parameters as before +
oxford = 192
embankment = 87
max_people_at_station = 20

# Initialize a LP model
m3 = gp.Model()

# Variables: z(s1, s2, t) represents the flow leaving from s1 towards s2 at instant t
z = {}
for (s1, s2), d in duration.items():
  for t in range(T+1):
    if t + d <= T:
      z[(s1, s2, t)] = m3.addVar(lb=0, ub=c[((s1, s2))], vtype=gp.GRB.INTEGER) # Note we already included the non-negativity and capacity constraints

# Add constraints
# 1) Security constraint for #192 to #87
# 2) Conservation of flow constraint subject to time-constraint
for s in stations_rest:
  if s == oxford or s == embankment:
     for t in range(T+1):
      m3.addConstr(sum(z.get((s, n, t), 0) for n in stations_rest) <= max_people_at_station)
  if s == origin or s == destination: continue
  else:
    # flow entering a node = flow leaving it at any given time
    for t in range(T+1):
      m3.addConstr(sum(z.get((s, n, t), 0) for n in stations_rest) == \
                   sum(z.get((n, s, t - duration.get((n, s), 0)), 0) for n in stations_rest))

# Set objective function: maximize net flux arriving at Victoria during the 18 minutes
obj_fun_3 = sum(z.get((n, destination, t), 0) - z.get((destination, n, t), 0)
                for n in stations_rest for t in range(T+1))

m3.setObjective(obj_fun_3, gp.GRB.MAXIMIZE)

# Optimize the model
m3.optimize()
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 418 rows, 1136 columns and 2240 nonzeros
# Model fingerprint: 0x5b6cd8d3
# Variable types: 0 continuous, 1136 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [5e+00, 2e+01]
#   RHS range        [2e+01, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 299 rows and 781 columns
# Presolve time: 0.01s
# Presolved: 119 rows, 355 columns, 712 nonzeros
# Found heuristic solution: objective 14.0000000
# Variable types: 0 continuous, 355 integer (0 binary)
# Found heuristic solution: objective 21.0000000
#
# Root relaxation: objective 1.100000e+02, 111 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     110.0000000  110.00000  0.00%     -    0s
#
# Explored 1 nodes (111 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 4: 110 21 14 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.100000000000e+02, best bound 1.100000000000e+02, gap 0.0000%

# %%
# Output of the results
print(f"\nMaximum flow for evacuation under 18 min from station 145 to 273 (under addtional constraints): {m3.objVal}")

for (st1, st2, t), z_opt in sorted(z.items(), key=lambda item: item[0][2]):  # Sort by t
    if z_opt.X > 0:  # Only care about positive flows
        print(f"Flow from station {st1} to station {st2} @ instant {t}: {z_opt.X}")
# Out:
# Maximum flow for evacuation under 18 min from station 145 to 273 (under addtional constraints): 110.0
# Flow from station 145 to station 89 @ instant 0: 14.0
# Flow from station 145 to station 90 @ instant 0: 21.0
# Flow from station 273 to station 107 @ instant 0: 7.0
# Flow from station 145 to station 223 @ instant 0: 8.0
# Flow from station 273 to station 248 @ instant 0: 11.0
# Flow from station 145 to station 89 @ instant 1: 14.0
# Flow from station 145 to station 90 @ instant 1: 21.0
# Flow from station 273 to station 107 @ instant 1: 7.0
# Flow from station 145 to station 223 @ instant 1: 8.0
# Flow from station 273 to station 248 @ instant 1: 11.0
# Flow from station 145 to station 89 @ instant 2: 14.0
# Flow from station 89 to station 277 @ instant 2: 14.0
# Flow from station 90 to station 104 @ instant 2: 21.0
# Flow from station 145 to station 90 @ instant 2: 21.0
# Flow from station 107 to station 285 @ instant 2: 7.0
# Flow from station 223 to station 126 @ instant 2: 8.0
# Flow from station 248 to station 273 @ instant 2: 11.0
# Flow from station 273 to station 248 @ instant 2: 11.0
# Flow from station 145 to station 89 @ instant 3: 14.0
# Flow from station 89 to station 277 @ instant 3: 14.0
# Flow from station 90 to station 104 @ instant 3: 5.0
# Flow from station 90 to station 145 @ instant 3: 16.0
# Flow from station 145 to station 90 @ instant 3: 21.0
# Flow from station 277 to station 102 @ instant 3: 7.0
# Flow from station 107 to station 285 @ instant 3: 2.0
# Flow from station 107 to station 197 @ instant 3: 5.0
# Flow from station 223 to station 126 @ instant 3: 8.0
# Flow from station 145 to station 223 @ instant 3: 8.0
# Flow from station 277 to station 192 @ instant 3: 7.0
# Flow from station 248 to station 273 @ instant 3: 11.0
# Flow from station 273 to station 248 @ instant 3: 11.0
# Flow from station 104 to station 11 @ instant 4: 21.0
# Flow from station 197 to station 49 @ instant 4: 5.0
# Flow from station 126 to station 60 @ instant 4: 7.0
# Flow from station 145 to station 89 @ instant 4: 7.0
# Flow from station 89 to station 277 @ instant 4: 14.0
# Flow from station 90 to station 104 @ instant 4: 21.0
# Flow from station 145 to station 90 @ instant 4: 21.0
# Flow from station 277 to station 102 @ instant 4: 7.0
# Flow from station 273 to station 107 @ instant 4: 7.0
# Flow from station 126 to station 259 @ instant 4: 1.0
# Flow from station 277 to station 192 @ instant 4: 7.0
# Flow from station 248 to station 273 @ instant 4: 2.0
# Flow from station 248 to station 285 @ instant 4: 9.0
# Flow from station 104 to station 11 @ instant 5: 5.0
# Flow from station 126 to station 60 @ instant 5: 8.0
# Flow from station 60 to station 151 @ instant 5: 7.0
# Flow from station 145 to station 89 @ instant 5: 14.0
# Flow from station 89 to station 277 @ instant 5: 14.0
# Flow from station 90 to station 145 @ instant 5: 21.0
# Flow from station 102 to station 259 @ instant 5: 7.0
# Flow from station 277 to station 102 @ instant 5: 7.0
# Flow from station 192 to station 107 @ instant 5: 7.0
# Flow from station 273 to station 107 @ instant 5: 3.0
# Flow from station 223 to station 126 @ instant 5: 8.0
# Flow from station 277 to station 192 @ instant 5: 7.0
# Flow from station 248 to station 273 @ instant 5: 11.0
# Flow from station 273 to station 248 @ instant 5: 4.0
# Flow from station 285 to station 248 @ instant 5: 7.0
# Flow from station 104 to station 11 @ instant 6: 21.0
# Flow from station 49 to station 87 @ instant 6: 5.0
# Flow from station 151 to station 49 @ instant 6: 7.0
# Flow from station 60 to station 151 @ instant 6: 8.0
# Flow from station 145 to station 89 @ instant 6: 14.0
# Flow from station 89 to station 277 @ instant 6: 7.0
# Flow from station 277 to station 89 @ instant 6: 5.0
# Flow from station 90 to station 104 @ instant 6: 21.0
# Flow from station 145 to station 90 @ instant 6: 10.0
# Flow from station 102 to station 259 @ instant 6: 7.0
# Flow from station 277 to station 102 @ instant 6: 2.0
# Flow from station 107 to station 285 @ instant 6: 6.0
# Flow from station 192 to station 107 @ instant 6: 7.0
# Flow from station 107 to station 273 @ instant 6: 1.0
# Flow from station 145 to station 223 @ instant 6: 8.0
# Flow from station 259 to station 151 @ instant 6: 4.0
# Flow from station 277 to station 192 @ instant 6: 7.0
# Flow from station 285 to station 248 @ instant 6: 11.0
# Flow from station 259 to station 28 @ instant 6: 4.0
# Flow from station 11 to station 104 @ instant 7: 11.0
# Flow from station 11 to station 28 @ instant 7: 10.0
# Flow from station 28 to station 107 @ instant 7: 4.0
# Flow from station 151 to station 49 @ instant 7: 7.0
# Flow from station 87 to station 285 @ instant 7: 5.0
# Flow from station 89 to station 145 @ instant 7: 12.0
# Flow from station 145 to station 89 @ instant 7: 14.0
# Flow from station 89 to station 277 @ instant 7: 7.0
# Flow from station 102 to station 259 @ instant 7: 7.0
# Flow from station 107 to station 285 @ instant 7: 10.0
# Flow from station 192 to station 107 @ instant 7: 7.0
# Flow from station 126 to station 259 @ instant 7: 5.0
# Flow from station 126 to station 223 @ instant 7: 3.0
# Flow from station 259 to station 151 @ instant 7: 2.0
# Flow from station 151 to station 197 @ instant 7: 5.0
# Flow from station 277 to station 192 @ instant 7: 7.0
# Flow from station 248 to station 273 @ instant 7: 11.0
# Flow from station 259 to station 28 @ instant 7: 5.0
# Flow from station 11 to station 212 @ instant 8: 5.0
# Flow from station 104 to station 11 @ instant 8: 21.0
# Flow from station 28 to station 107 @ instant 8: 5.0
# Flow from station 49 to station 87 @ instant 8: 7.0
# Flow from station 151 to station 49 @ instant 8: 1.0
# Flow from station 145 to station 89 @ instant 8: 5.0
# Flow from station 89 to station 277 @ instant 8: 14.0
# Flow from station 90 to station 104 @ instant 8: 10.0
# Flow from station 102 to station 259 @ instant 8: 2.0
# Flow from station 107 to station 285 @ instant 8: 4.0
# Flow from station 192 to station 107 @ instant 8: 7.0
# Flow from station 107 to station 273 @ instant 8: 3.0
# Flow from station 223 to station 126 @ instant 8: 8.0
# Flow from station 145 to station 223 @ instant 8: 8.0
# Flow from station 259 to station 151 @ instant 8: 2.0
# Flow from station 151 to station 197 @ instant 8: 1.0
# Flow from station 259 to station 192 @ instant 8: 5.0
# Flow from station 277 to station 192 @ instant 8: 7.0
# Flow from station 248 to station 273 @ instant 8: 10.0
# Flow from station 248 to station 285 @ instant 8: 1.0
# Flow from station 11 to station 104 @ instant 9: 19.0
# Flow from station 11 to station 28 @ instant 9: 2.0
# Flow from station 28 to station 11 @ instant 9: 1.0
# Flow from station 28 to station 107 @ instant 9: 9.0
# Flow from station 49 to station 87 @ instant 9: 7.0
# Flow from station 151 to station 49 @ instant 9: 2.0
# Flow from station 87 to station 285 @ instant 9: 7.0
# Flow from station 89 to station 277 @ instant 9: 14.0
# Flow from station 277 to station 89 @ instant 9: 9.0
# Flow from station 259 to station 102 @ instant 9: 7.0
# Flow from station 107 to station 285 @ instant 9: 4.0
# Flow from station 197 to station 107 @ instant 9: 5.0
# Flow from station 192 to station 107 @ instant 9: 7.0
# Flow from station 107 to station 273 @ instant 9: 7.0
# Flow from station 223 to station 145 @ instant 9: 3.0
# Flow from station 277 to station 192 @ instant 9: 5.0
# Flow from station 285 to station 248 @ instant 9: 11.0
# Flow from station 192 to station 28 @ instant 10: 5.0
# Flow from station 49 to station 87 @ instant 10: 1.0
# Flow from station 87 to station 285 @ instant 10: 7.0
# Flow from station 89 to station 145 @ instant 10: 14.0
# Flow from station 277 to station 89 @ instant 10: 13.0
# Flow from station 104 to station 90 @ instant 10: 21.0
# Flow from station 102 to station 277 @ instant 10: 7.0
# Flow from station 107 to station 285 @ instant 10: 10.0
# Flow from station 197 to station 107 @ instant 10: 1.0
# Flow from station 192 to station 107 @ instant 10: 7.0
# Flow from station 107 to station 273 @ instant 10: 7.0
# Flow from station 126 to station 259 @ instant 10: 5.0
# Flow from station 126 to station 223 @ instant 10: 3.0
# Flow from station 223 to station 126 @ instant 10: 8.0
# Flow from station 145 to station 223 @ instant 10: 5.0
# Flow from station 212 to station 192 @ instant 10: 5.0
# Flow from station 277 to station 192 @ instant 10: 1.0
# Flow from station 285 to station 248 @ instant 10: 11.0
# Flow from station 11 to station 104 @ instant 11: 20.0
# Flow from station 11 to station 28 @ instant 11: 2.0
# Flow from station 28 to station 107 @ instant 11: 7.0
# Flow from station 49 to station 87 @ instant 11: 1.0
# Flow from station 49 to station 197 @ instant 11: 1.0
# Flow from station 87 to station 285 @ instant 11: 1.0
# Flow from station 89 to station 145 @ instant 11: 13.0
# Flow from station 107 to station 285 @ instant 11: 10.0
# Flow from station 107 to station 273 @ instant 11: 7.0
# Flow from station 145 to station 223 @ instant 11: 8.0
# Flow from station 192 to station 197 @ instant 11: 5.0
# Flow from station 248 to station 273 @ instant 11: 11.0
# Flow from station 285 to station 248 @ instant 11: 11.0
# Flow from station 192 to station 28 @ instant 12: 5.0
# Flow from station 126 to station 60 @ instant 12: 3.0
# Flow from station 87 to station 285 @ instant 12: 1.0
# Flow from station 104 to station 90 @ instant 12: 19.0
# Flow from station 90 to station 145 @ instant 12: 21.0
# Flow from station 192 to station 107 @ instant 12: 1.0
# Flow from station 107 to station 273 @ instant 12: 7.0
# Flow from station 259 to station 126 @ instant 12: 5.0
# Flow from station 126 to station 223 @ instant 12: 5.0
# Flow from station 145 to station 223 @ instant 12: 3.0
# Flow from station 223 to station 145 @ instant 12: 8.0
# Flow from station 277 to station 192 @ instant 12: 7.0
# Flow from station 248 to station 273 @ instant 12: 11.0
# Flow from station 285 to station 248 @ instant 12: 11.0
# Flow from station 28 to station 107 @ instant 13: 7.0
# Flow from station 60 to station 126 @ instant 13: 3.0
# Flow from station 197 to station 107 @ instant 13: 6.0
# Flow from station 107 to station 273 @ instant 13: 7.0
# Flow from station 145 to station 223 @ instant 13: 8.0
# Flow from station 223 to station 145 @ instant 13: 8.0
# Flow from station 248 to station 273 @ instant 13: 11.0
# Flow from station 285 to station 248 @ instant 13: 11.0
# Flow from station 104 to station 90 @ instant 14: 20.0
# Flow from station 90 to station 145 @ instant 14: 19.0
# Flow from station 192 to station 107 @ instant 14: 7.0
# Flow from station 107 to station 273 @ instant 14: 7.0
# Flow from station 126 to station 223 @ instant 14: 8.0
# Flow from station 223 to station 145 @ instant 14: 8.0
# Flow from station 248 to station 273 @ instant 14: 11.0
# Flow from station 285 to station 248 @ instant 14: 11.0
# Flow from station 107 to station 273 @ instant 15: 7.0
# Flow from station 223 to station 145 @ instant 15: 8.0
# Flow from station 248 to station 273 @ instant 15: 11.0
# Flow from station 90 to station 145 @ instant 16: 20.0
# Flow from station 107 to station 273 @ instant 16: 7.0
# Flow from station 223 to station 145 @ instant 16: 8.0
# Flow from station 248 to station 273 @ instant 16: 11.0

# %% [markdown]
# #Problem 4:#

# %% [markdown]
# **Improvement Idea 1:** capacity improvement for 3 connections.

# %%
# P4: +2 Capacity improvements on 3 connections.

# Suppose we have the budget to improve 3 of the connections i, j in problem 1 by 2 units.
# We have to choose which lines to improve based on which is going to most increment the overall flow from source to sink.

# Fixed parameters
stations = set(df['station1']).union(set(df['station2'])) # List all unique stations
source = 110
sink = 145

# Initialize a LP model
m4_cap = gp.Model()

# Variables: x[i, j] >= 0 representing the flow from station i to j
# One variable for each arc with positive capacity
# One binary variable for each arc to account for the improvement.

x = {}
imp = {}

for (s1, s2), capacity in c.items():
  x[(s1, s2)] = m4_cap.addVar(lb=0, vtype=gp.GRB.INTEGER) # Note we already included the non-negativity constraints.
  imp[(s1, s2)] = m4_cap.addVar(vtype=gp.GRB.BINARY)

# New Capacity Constraints
for (s1, s2), capacity in c.items():
  m4_cap.addConstr(x[(s1, s2)] <= capacity + 2 * imp[(s1, s2)]) #Add 2 capacity units if choose to improve

#improve at most 3 connections
m4_cap.addConstr(sum(imp[(n1, n2)] for (n1, n2), capacity in c.items()) <= 3)

# Add conservation of flow constraint
for s in stations:
  if s == source or s == sink: continue
  else:
    # flow entering a node = flow leaving it
    m4_cap.addConstr(sum(x[(n, s)] for n in stations if (n, s) in x) == sum(x[(s, n)] for n in stations if (s, n) in x))

# Set objective function: maximize net flux arriving at Hammersmith
# Note: maximizing net flux leaving King's cross would be equivalent
m4_cap.setObjective(sum(x[(n, sink)] - x[(sink, n)] for n in stations if (n, sink) in x), gp.GRB.MAXIMIZE)

# Optimize the model
m4_cap.optimize()
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1073 rows, 1504 columns and 3738 nonzeros
# Model fingerprint: 0x3a2ced71
# Variable types: 0 continuous, 1504 integer (752 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 662 rows and 944 columns
# Presolve time: 0.02s
# Presolved: 411 rows, 560 columns, 1466 nonzeros
# Variable types: 0 continuous, 560 integer (364 binary)
#
# Root relaxation: objective 3.628571e+01, 238 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   36.28571    0   11   -0.00000   36.28571      -     -    0s
# H    0     0                      36.0000000   36.28571  0.79%     -    0s
#      0     0   36.28571    0   11   36.00000   36.28571  0.79%     -    0s
#
# Explored 1 nodes (262 simplex iterations) in 0.07 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: 36 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.600000000000e+01, best bound 3.600000000000e+01, gap 0.0000%

# %%
# Output of Results
print (f"\nMaximum flow from station 145 to 110 with improvements:  {m4_cap.objVal}")
print ("\nImproved Connections:")
for (n1, n2), var in imp.items():
  if var.X == 1:
    print(f"Connection from station {n1} to station {n2}")
# Out:
# Maximum flow from station 145 to 110 with improvements:  36.0
#
# Improved Connections:
# Connection from station 110 to station 17
# Connection from station 17 to station 74

# %% [markdown]
#  **Improvement Idea 2:** choose 1 line to improve by 2 capacity units. (This could equal an improvement of the trains for a certain line)

# %%
#P4: +2 capacity on Line improvement (new trains for line X)

c = {}

#Store all the capacities of the links and their respective lines.

for index, row in df.iterrows():

  s1 = int(row['station1'])
  s2 = int(row['station2'])
  line_id = row['line']
  capacity_line = int(row['line_capacity'])

  if (s1, s2) not in c:
        c[(s1, s2)] = {}
        c[(s2, s1)] = {}

  # This time, we store the information more granularly by saving each link, and not adding up every capacity yet.
  c[(s1, s2)][line_id] = capacity_line
  c[(s2, s1)][line_id] = capacity_line

stations = set(df['station1']).union(set(df['station2'])) # List all unique stations
source = 110
sink = 145

# Initialize a LP model
m4_lin = gp.Model()

# Variables: x[i, j] >= 0 representing the flow frow station i to j

# One variable for each arc with positive capacity
x = {}
for (s1, s2), capacity in c.items():
  x[(s1, s2)] = m4_lin.addVar(lb=0, vtype=gp.GRB.INTEGER) # Note we already included the non-negativity and capacity constraints

# Variables for which line to improve
y = {}
for line in lines:
    y[line] = m4_lin.addVar(vtype=gp.GRB.BINARY)

# Capacity constraints keeping in mind the line improvement
for (s1, s2), capacities in c.items():
    m4_lin.addConstr(
        x[(s1, s2)] <= sum(cap + (2 * y[line]) for line, cap in capacities.items())
    )

#Improve at most 1 line
m4_lin.addConstr(sum(y[line] for line in lines) <=1)

# Add conservation of flow constraint
for s in stations:
  if s == source or s == sink: continue
  else:
    # flow entering a node = flow leaving it
    m4_lin.addConstr(sum(x[(n, s)] for n in stations if (n, s) in x) == sum(x[(s, n)] for n in stations if (s, n) in x))

# Set objective function: maximize net flux arriving at Hammersmith
# Note: maximizing net flux leaving King's cross would be equivalent
m4_lin.setObjective(sum(x[(n, sink)] - x[(sink, n)] for n in stations if (n, sink) in x), gp.GRB.MAXIMIZE)

# Optimize the model
m4_lin.optimize()
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1073 rows, 766 columns and 3114 nonzeros
# Model fingerprint: 0x804b5a1f
# Variable types: 0 continuous, 766 integer (14 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 832 rows and 556 columns
# Presolve time: 0.01s
# Presolved: 241 rows, 210 columns, 828 nonzeros
# Variable types: 0 continuous, 210 integer (14 binary)
#
# Root relaxation: objective 3.700000e+01, 119 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   37.00000    0    2   -0.00000   37.00000      -     -    0s
# H    0     0                      36.0000000   37.00000  2.78%     -    0s
# *    0     0               0      37.0000000   37.00000  0.00%     -    0s
#
# Explored 1 nodes (120 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 3: 37 36 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.700000000000e+01, best bound 3.700000000000e+01, gap 0.0000%

# %%
#Output of Results
print("\nThe new max flow from Station 143 to Station 110 is: ", m4_lin.ObjVal)

for line in lines:
   if y[line].x > 0.5: print(f"\nNew trains for line {line}")
# Out:
# The new max flow from Station 143 to Station 110 is:  37.0
#
# New trains for line 10
